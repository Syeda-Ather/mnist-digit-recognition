# %% [markdown]
# ### **MNIST_Digit_Recognition**

# %%
# import Libraries

import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

# %%
# Load the Dataset

  (X_train, y_train), (X_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %% [markdown]
# ## **Understand the Dataset**

# %%
print("Training data shape:", X_train.shape)
print("Testing data shape:", X_test.shape)
print("Training labels shape:", y_train.shape)
print("Testing labels shape:", y_test.shape)
# Out:
# Training data shape: (60000, 28, 28)
# Testing data shape: (10000, 28, 28)
# Training labels shape: (60000,)
# Testing labels shape: (10000,)

# %%
print("Image shape:", X_train[0].shape)
print("First label:", y_train[0])
# Out:
# Image shape: (28, 28)
# First label: 5

# %% [markdown]
# ## **Display Sample Images**

# %%
plt.figure(figsize=(6,4))

for i in range(10):
    plt.subplot(2, 5, i + 1)
    plt.imshow(X_train[i], cmap='gray')
    plt.title(f"Label: {y_train[i]}")
    plt.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## **Normalize the Image Data**

# %%
X_train = X_train / 255.0
X_test = X_test / 255.0

# %% [markdown]
# ## **Encode the Labels**

# %%
y_train_encoded = to_categorical(y_train, 10)
y_test_encoded = to_categorical(y_test, 10)

# %% [markdown]
# ## **Build the Neural Network Model**

# %%
from tensorflow.keras.layers import Input

model = Sequential([
    Input(shape=(28, 28)),
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.3),
    Dense(64, activation='relu'),
    Dropout(0.2),
    Dense(10, activation='softmax')
])

# %% [markdown]
# ## **Compile the Model**

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# ## **Train the Model**

# %%
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=2,
    restore_best_weights=True
)

history = model.fit(
    X_train,
    y_train_encoded,
    epochs=10,
    batch_size=32,
    validation_split=0.2,
    callbacks=[early_stop]
)
# Out:
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.8803 - loss: 0.3938 - val_accuracy: 0.9553 - val_loss: 0.1535
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9392 - loss: 0.2041 - val_accuracy: 0.9634 - val_loss: 0.1242
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9512 - loss: 0.1632 - val_accuracy: 0.9672 - val_loss: 0.1048
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9590 - loss: 0.1335 - val_accuracy: 0.9705 - val_loss: 0.0958
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9632 - loss: 0.1222 - val_accuracy: 0.9712 - val_loss: 0.0970
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9656 - loss: 0.1108 - val_accuracy: 0.9746 - val_loss: 0.0877
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9686 - loss: 0.1019 - val_accuracy: 0.9752 - val_loss: 0.0883
# Epoch 8/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9690 - loss: 0.0957 - val_accuracy: 0.9763 - val_loss: 0.0845
# Epoch 9/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9718 - loss: 0.0880 - val_accuracy: 0.9769 - val_loss: 0.0854
# Epoch 10/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9744 - loss: 0.0826 - val_accuracy: 0.9762 - val_loss: 0.0874

# %% [markdown]
# ## **Evaluate the Model**

# %%
print("Training Accuracy:", history.history['accuracy'][-1])
print("Validation Accuracy:", history.history['val_accuracy'][-1])

test_loss, test_accuracy = model.evaluate(X_test, y_test_encoded)
print("Test Accuracy:", test_accuracy)
# Out:
# Training Accuracy: 0.9743750095367432
# Validation Accuracy: 0.9762499928474426
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9760 - loss: 0.0797
# Test Accuracy: 0.9760000109672546

# %% [markdown]
# ## **Plot Training and Validation Accuracy**

# %%
plt.figure(figsize=(7, 4))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training vs Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ## **Plot Training and Validation Loss**

# %%
plt.figure(figsize=(7, 4))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training vs Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# ## **Make Predictions**

# %%
y_pred_probs = model.predict(X_test)
y_pred = np.argmax(y_pred_probs, axis=1)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %% [markdown]
# ### **Classification Report**

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98       980
#            1       0.99      0.99      0.99      1135
#            2       0.98      0.97      0.98      1032
#            3       0.97      0.98      0.98      1010
#            4       0.98      0.97      0.97       982
#            5       0.97      0.97      0.97       892
#            6       0.97      0.98      0.98       958
#            7       0.97      0.97      0.97      1028
#            8       0.97      0.97      0.97       974
#            9       0.97      0.96      0.97      1009
#
#     accuracy                           0.98     10000
#    macro avg       0.98      0.98      0.98     10000
# weighted avg       0.98      0.98      0.98     10000

# %% [markdown]
# ## **Confusion Matrix**

# %%
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(9, 7))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %% [markdown]
# ## **Test the Model on Sample Images**

# %%
plt.figure(figsize=(6, 4))

for i in range(10):
    plt.subplot(2, 5, i + 1)
    plt.imshow(X_test[i], cmap='gray')
    plt.title(f"Pred: {y_pred[i]}")
    plt.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## **Save the Model**

# %%
model.save("mnist_digit_model.keras")
